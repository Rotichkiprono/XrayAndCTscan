# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **IMPORTING REQIRED LIBRARIES**

# %%
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns  # For enhanced visualizations
import os  # For operating system functionalities like file paths
import cv2  # For image processing
import tensorflow as tf  # Core library for building ML models
from tensorflow import keras  # High-level neural network API
from keras.callbacks import EarlyStopping, ModelCheckpoint  # For controlling training
from tensorflow.keras import regularizers  # For adding regularization to layers
from sklearn.metrics import (  # For model evaluation
    confusion_matrix, accuracy_score, ConfusionMatrixDisplay, classification_report)
from sklearn.model_selection import train_test_split  # For splitting the dataset
from sklearn.preprocessing import LabelEncoder  # For encoding labels
from tqdm import tqdm  # For showing progress bars
import warnings  # For handling warnings

# Suppress warnings for cleaner output during development
warnings.filterwarnings('ignore')

# %% [markdown]
# # **DATASET**

# %%
import os
import glob
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# Define the path to the dataset
image_data = Path('/content/drive/MyDrive/BACKUPS/Datasets/XrayDataset')

# Get a list of all image file paths in the dataset
train_files = list(image_data.glob('**/*.*'))  # Get all image files in subdirectories
np.random.shuffle(train_files)  # Shuffle the file paths

# Extract labels from the directory structure using pathlib
train_labels = [path.parent.name for path in train_files]

# Create a zip object containing file paths and corresponding labels
train_data = zip(train_files, train_labels)

# Convert the data into a pandas DataFrame
train_df = pd.DataFrame(train_data, columns=["Image", "Label"])

# Display the resulting DataFrame (Optional)
print(train_df.head())  # Display only the first few rows for verification
# Out:
#                                                Image         Label
# 0  /content/drive/MyDrive/BACKUPS/Datasets/XrayDa...     PNEUMONIA
# 1  /content/drive/MyDrive/BACKUPS/Datasets/XrayDa...   NORMAL XRAY
# 2  /content/drive/MyDrive/BACKUPS/Datasets/XrayDa...       COVID19
# 3  /content/drive/MyDrive/BACKUPS/Datasets/XrayDa...   NORMAL XRAY
# 4  /content/drive/MyDrive/BACKUPS/Datasets/XrayDa...     PNEUMONIA

# %% [markdown]
# # **VISUALISING THE DATA**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to visualize label distribution
def plot_label_distribution(dataframe, label_column, title="Label Distribution with Percentages", palette_name="pastel"):
    try:
        # Set a theme for better aesthetics
        sns.set_theme(style="whitegrid")

        # Calculate counts and percentages for each label
        label_counts = dataframe[label_column].value_counts()
        label_percentages = (label_counts / label_counts.sum() * 100).round(2)  # Calculate percentage

        # Print percentage for each label (optional)
        print("Label Percentages:")
        print(label_percentages)

        # Sort the labels based on count values in descending order
        sorted_labels = label_counts.index

        # Create a color palette for the bars
        palette = sns.color_palette(palette_name, len(sorted_labels))

        # Plot the count plot with sorted labels
        plt.figure(figsize=(12, 6))
        ax = sns.countplot(x=dataframe[label_column], order=sorted_labels, palette=palette)

        # Annotate each bar with the percentage value
        for bar in ax.patches:
            height = bar.get_height()  # Get the height of the bar
            percentage = f'{(height / label_counts.sum()) * 100:.2f}%'  # Calculate percentage
            ax.annotate(percentage,  # The label to be annotated
                        (bar.get_x() + bar.get_width() / 2., height),  # Position of the label
                        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 8), textcoords='offset points')

        # Rotate x-axis labels for better visibility and set the label font size
        plt.xticks(rotation=0, ha='center', fontsize=12)

        # Add title and labels with improved fonts and padding
        plt.title(title, fontsize=16, pad=20)
        plt.xlabel("Labels", fontsize=14, labelpad=10)
        plt.ylabel("Count", fontsize=14, labelpad=10)

        # Remove the top and right spines for a cleaner look
        sns.despine()

        # Show the plot with adjusted layout
        plt.tight_layout()
        plt.show()

    except KeyError as e:
        print(f"Error: The label column '{label_column}' is not present in the DataFrame.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %% [markdown]
# **Visualising training dataframe**

# %%
plot_label_distribution(train_df, label_column="Label", title="Chest X-Ray Label Distribution")
# Out:
# Label Percentages:
# Label
# PNEUMONIA        38.64
#  NORMAL XRAY     34.07
# TURBERCULOSIS    14.97
# COVID19          12.32
# Name: count, dtype: float64

# %% [markdown]
# # **SPLITING DATA INTO TRAINING & VALIDATION SET**

# %% [markdown]
# **VARIABLES**

# %%
train_data_dir = image_data
batch_size = 8
target_size = (224, 224)
validation_split = 0.25  # Total split for validation + test
seed = 100

# %% [markdown]
# **LOAD TRAINING DATASET**

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split=validation_split,
    subset="training",
    seed=seed,
    image_size=target_size,
    batch_size=batch_size,
)
# Out:
# Found 4676 files belonging to 4 classes.
# Using 3507 files for training.

# %% [markdown]
# **VALIDATION & TEST DATASET**

# %%
val_test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split=validation_split,
    subset="validation",
    seed=seed,
    image_size=target_size,
    batch_size=batch_size,
)
# Out:
# Found 4676 files belonging to 4 classes.
# Using 1169 files for validation.

# %% [markdown]
# **SPLITTING VALIDATION & TEST DATASET**

# %%
val_size = len(val_test_dataset) // 2  # Split validation and test equally
validation_dataset = val_test_dataset.take(val_size)
test_dataset = val_test_dataset.skip(val_size)

# %% [markdown]
# **CALCULATING SAMPLE COUNTS**

# %%
train_samples = len(train_dataset) * batch_size
val_samples = len(validation_dataset) * batch_size
test_samples = len(test_dataset) * batch_size

print(f"Training samples: {train_samples}")
print(f"Validation samples: {val_samples}")
print(f"Test samples: {test_samples}")
# Out:
# Training samples: 3512
# Validation samples: 584
# Test samples: 592

# %% [markdown]
# **VISUALIZING THE DATASET DISTRIBUTION**

# %%
# Names for the datasets
datasets = ['Training', 'Validation', 'Test']
sample_counts = [train_samples, val_samples, test_samples]

# Plotting
plt.figure(figsize=(5, 6))
plt.bar(datasets, sample_counts, color=['blue', 'orange', 'green'])
plt.xlabel('Dataset', fontsize=14)
plt.ylabel('Number of Samples', fontsize=14)
plt.title('Sample Distribution in Datasets', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0, max(sample_counts) + 100)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **EXPLORING THE DATASET**

# %%
# Extract class names and configure plot dimensions
class_names = train_dataset.class_names
num_images_per_class = 2
num_classes = len(class_names)

# Initialize a dictionary to track displayed image counts per class
count = {class_name: 0 for class_name in class_names}

# Create the plot with dynamic size
plt.figure(figsize=(15, num_classes * 3))  # Adjusted height dynamically based on number of classes

# Loop through the dataset to display images
for images, labels in train_dataset.take(1):
    # Loop through each image and its corresponding label
    for i in range(len(labels)):
        label = class_names[labels[i].numpy()]  # Convert label tensor to NumPy for indexing
        # Check if the required number of images has been displayed for the current class
        if count[label] < num_images_per_class:
            # Calculate the position of the subplot (dynamically arranged)
            subplot_position = count[label] + 1 + num_images_per_class * class_names.index(label)
            ax = plt.subplot(num_classes, num_images_per_class, subplot_position)

            # Display the image with the correct title
            ax.imshow(images[i].numpy().astype("uint8"))
            ax.set_title(label, fontsize=12)
            ax.axis("off")  # Remove axis ticks and labels

            # Update the counter for the class
            count[label] += 1

        # Break the loop when all required images for each class are displayed
        if sum(count.values()) >= num_images_per_class * num_classes:
            break

# Adjust layout for better spacing and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **MODELING**

# %%
# Load the base model
base_model = tf.keras.applications.ConvNeXtTiny(input_shape=(224, 224, 3),
                                                include_top=False,
                                                weights='imagenet')

# Freeze layers until the last few blocks of the base model
for layer in base_model.layers[:-20]:  # Freeze all layers except the last 20
    layer.trainable = False

# Create the Keras model
keras_model = keras.models.Sequential()
keras_model.add(base_model)
keras_model.add(keras.layers.GlobalAveragePooling2D())
keras_model.add(keras.layers.Dense(256, activation=None, kernel_regularizer=tf.keras.regularizers.l2(0.001)))
keras_model.add(keras.layers.BatchNormalization())
keras_model.add(keras.layers.Activation('relu'))
keras_model.add(keras.layers.Dropout(0.5))
keras_model.add(keras.layers.Dense(4, activation=tf.nn.softmax))

# Print the model summary
keras_model.summary()

# Compile the model with an optimizer, loss, and metrics
keras_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),  # Use lower learning rate
                    loss='categorical_crossentropy',  # For multi-class classification
                    metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ convnext_tiny (Functional)           │ (None, 7, 7, 768)           │      27,820,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_2           │ (None, 768)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,019,044 (106.88 MB)
#  Trainable params: 14,449,412 (55.12 MB)
#  Non-trainable params: 13,569,632 (51.76 MB)

# %% [markdown]
# # **TRAINING**

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Compile the model with optimizer, learning rate, and loss
optimizer = keras.optimizers.Adam(learning_rate=1e-5)
keras_model.compile(optimizer=optimizer,
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

# Callbacks for early stopping and learning rate scheduling
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Train the model
history = keras_model.fit(train_dataset, validation_data=validation_dataset,
                          epochs=10, callbacks=[early_stopping, lr_scheduler])

# Evaluate the model on the test dataset
test_loss, test_accuracy = keras_model.evaluate(test_dataset)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 86s 150ms/step - accuracy: 0.4692 - loss: 1.7044 - val_accuracy: 0.8767 - val_loss: 0.7754 - learning_rate: 1.0000e-05
# Epoch 2/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 68s 136ms/step - accuracy: 0.7652 - loss: 1.0244 - val_accuracy: 0.9110 - val_loss: 0.6527 - learning_rate: 1.0000e-05
# Epoch 3/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 78s 128ms/step - accuracy: 0.8384 - loss: 0.8451 - val_accuracy: 0.9281 - val_loss: 0.5962 - learning_rate: 1.0000e-05
# Epoch 4/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 126ms/step - accuracy: 0.8686 - loss: 0.7624 - val_accuracy: 0.9349 - val_loss: 0.5689 - learning_rate: 1.0000e-05
# Epoch 5/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 82s 127ms/step - accuracy: 0.8867 - loss: 0.7198 - val_accuracy: 0.9401 - val_loss: 0.5427 - learning_rate: 1.0000e-05
# Epoch 6/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 87s 139ms/step - accuracy: 0.9100 - loss: 0.6410 - val_accuracy: 0.9503 - val_loss: 0.5242 - learning_rate: 1.0000e-05
# Epoch 7/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 78s 129ms/step - accuracy: 0.9193 - loss: 0.6165 - val_accuracy: 0.9503 - val_loss: 0.5131 - learning_rate: 1.0000e-05
# Epoch 8/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 82s 130ms/step - accuracy: 0.9251 - loss: 0.6061 - val_accuracy: 0.9572 - val_loss: 0.4888 - learning_rate: 1.0000e-05
# Epoch 9/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 82s 129ms/step - accuracy: 0.9348 - loss: 0.5802 - val_accuracy: 0.9538 - val_loss: 0.4861 - learning_rate: 1.0000e-05
# Epoch 10/10
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 84s 134ms/step - accuracy: 0.9334 - loss: 0.5682 - val_accuracy: 0.9572 - val_loss: 0.4816 - learning_rate: 1.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9366 - loss: 0.5139
# Test Loss: 0.5188131332397461, Test Accuracy: 0.94017094373703

# %% [markdown]
# **SAVING THE TRAINED MODEL**

# %%
# Save the trained model
keras_model.save('/content/drive/MyDrive/BACKUPS/Datasets/XrayDataset/xray_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Save the trained model
keras_model.save('/content/drive/MyDrive/BACKUPS/Datasets/XrayDataset/xray_model.keras')

# %%
keras_model.export('/content/drive/MyDrive/BACKUPS/Datasets/XrayDataset/xraysecond_model')  # SavedModel format
# Out:
# Saved artifact at '/content/drive/MyDrive/BACKUPS/Datasets/XrayDataset/xraysecond_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_552')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   134802709043984: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   134802710812752: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   134802709165536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709350880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709352992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709354224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709360384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709353520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709358272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709356336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709362672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709363376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709361792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709398800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709403376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709410592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709407424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709408480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709406544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709412000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709481776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709486352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709493568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709490400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709491456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709489520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709492688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709487408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709404432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708835920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709568800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709570736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709573552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709571616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709576544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709572848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709576720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709627296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709628000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709627824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709631872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709629584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709636624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709640672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709641376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709642608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707613120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707612592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707614704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707617696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707618928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707622448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707626496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707627200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707696272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707695216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707695920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707697680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709562992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707699264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707704192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707708416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707776080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707706656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707778896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707708064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707782592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707779952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707777840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707778192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707784880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707789104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707789808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707787872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707849184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707846016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707847072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707841616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707854816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707856048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707856224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707930928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707928816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707926880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707926176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707924768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707938144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707936384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707937792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708012672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708009504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707932688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708010384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708013728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708016720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708020592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708020240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708124192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708124544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708124720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708124368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708128240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708131232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708132640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708135280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708134576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708176160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708174048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708172112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708173696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708178448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708182672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708183376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708183728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708177568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708289440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708287328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708286976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708295072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708381936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709348592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709046800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708388976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708387216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708383520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708292080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708393200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708394432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708397248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708396368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708454336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708452048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708457328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708455392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708458384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708459968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708462784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708516352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708517584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708520400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708517936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708515296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708523216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708520928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708527616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708528320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708526736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708612896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708617472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708624688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708621520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708623280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708623808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708625744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708626448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802708622224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706597488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706602064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706609280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706606112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706607168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706605232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706611568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706608400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706610688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706680464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706685040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706688384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706690144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802709164832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706907552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706913536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706915296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706912832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802706914064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707007440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134802707006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
